# %%
import yfinance as yf
datos = yf.download("AAPL", start ="2023-01-01", end="2023-12-31")
#print(datos) #muestra todos los datos pero con puntos suspensivos si es mucha data
#datos.head() #muestra una tabla pero solo los primero 5 filas
#print(type(datos)) #devuelve el tipo usado en este caso pandas
#print(datos.columns) #devuelve la informacion de las columnas dependiendo del ticket
print(datos.index) #devuelve la matriz de la
# Out:
# [*********************100%***********************]  1 of 1 completed
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17',
#                ...
#                '2023-12-15', '2023-12-18', '2023-12-19', '2023-12-20',
#                '2023-12-21', '2023-12-22', '2023-12-26', '2023-12-27',
#                '2023-12-28', '2023-12-29'],
#               dtype='datetime64[s]', name='Date', length=250, freq=None)

# %% [markdown]
# Alpha Vantage

# %%
import requests
url='https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=X98DW239FQD9E37O'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Information': 'Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints'}

# %% [markdown]
# Twelve Data

# %%
# !pip install twelvedata[pandas,matplotlib,plotly,websocket-client]

# %%
from twelvedata import TDClient

# Initialize client - apikey parameter is requiered
td = TDClient(apikey="38b6003151d0413eaa4bb77a0966226e")

# Construct the necessary time series
ts = td.time_series(
    symbol="FXAIX", #TODO DEPENDE DEL TICKET ESTA ES LA ESTRUCTURA BASE
    interval="1min",
    outputsize=10,
    timezone="America/New_York",
)

# Returns pandas.DataFrame
ts.as_pandas()
# Out:
#                           open       high        low      close
# datetime
# 2026-08-18 09:30:00  267.54001  267.54001  267.54001  267.54001
# 2026-08-17 09:30:00  269.39001  269.39001  269.39001  269.39001
# 2026-08-14 09:30:00  270.76999  270.76999  270.76999  270.76999
# 2026-08-13 09:30:00  271.20001  271.20001  271.20001  271.20001
# 2026-08-12 09:30:00  269.44000  269.44000  269.44000  269.44000
# 2026-08-11 09:30:00  268.72000  268.72000  268.72000  268.72000
# 2026-08-10 09:30:00  269.57999  269.57999  269.57999  269.57999
# 2026-08-07 09:30:00  269.70999  269.70999  269.70999  269.70999
# 2026-08-06 09:30:00  268.04001  268.04001  268.04001  268.04001
# 2026-08-05 09:30:00  268.51001  268.51001  268.51001  268.51001

# %% [markdown]
# Finnhub

# %%
# !pip uninstall -y websocket
# !pip install --force-reinstall websocket-client finnhub-python
# Out:
# WARNING: Skipping websocket as it is not installed.
# ...
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached finnhub_python-2.4.29-py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached charset_normalizer-3.5.1-cp314-cp314-win_amd64.whl.metadata (46 kB)
# ...
#   Using cached idna-3.19-py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Using cached finnhub_python-2.4.29-py3-none-any.whl (12 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached charset_normalizer-3.5.1-cp314-cp314-win_amd64.whl (204 kB)
# Using cached idna-3.19-py3-none-any.whl (68 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached certifi-2026.7.22-py3-none-any.whl (136 kB)
# ...
#
# ...

# %%
import finnhub

finnhub_client = finnhub.Client(api_key="da392apr01qupvfc52cgda392apr01qupvfc52d0")

# %%
import sys

sys.modules.pop("websocket", None)
import websocket

def on_message(ws, message):
    print(message)

def on_error(ws, error):
    print(error)

def on_close(ws, close_status_code, close_msg):
    print("### closed ###")

def on_open(ws):
    ws.send('{"type":"subscribe","symbol":"AAPL"}')
    ws.send('{"type":"subscribe","symbol":"AMZN"}')
    ws.send('{"type":"subscribe","symbol":"BINANCE:BTCUSDT"}')
    ws.send('{"type":"subscribe","symbol":"IC MARKETS:1"}')

if __name__ == "__main__":
    ws = websocket.WebSocketApp("wss://ws.finnhub.io?token=da392apr01qupvfc52cgda392apr01qupvfc52d0",
                                 on_message=on_message,
                                 on_error=on_error,
                                 on_close=on_close)
    ws.on_open = on_open
    ws.run_forever()
# Out:
# {"type":"trade","data":[{"t":1787207470856,"p":69649.99,"v":0.00008,"s":"BINANCE:BTCUSDT"},{"t":1787207470856,"p":69649.99,"v":0.00009,"s":"BINANCE:BTCUSDT"},{"t":1787207470856,"p":69649.99,"v":0.00001,"s":"BINANCE:BTCUSDT"}]}
# {"type":"trade","data":[{"t":1787207470078,"p":1.16774,"v":0,"s":"IC MARKETS:1"}]}
# {"type":"trade","data":[{"t":1787207471033,"p":69649.99,"v":0.00007,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00015,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00008,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00008,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00008,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00008,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00008,"s":"BINANCE:BTCUSDT"},{"t":1787207471033,"p":69649.99,"v":0.00952,"s":"BINANCE:BTCUSDT"}]}
# {"type":"trade","data":[{"t":1787207471644,"p":69649.99,"v":0.00015,"s":"BINANCE:BTCUSDT"}]}
# ...

# %% [markdown]
# Marketstack

# %%
import requests

url ="https://api.ipstack.com/?access_key=d1eded6c0098d3d93e45ae01101cf626"

querystring = {"symbols":"AAPL"}
response = requests.get(url, params=querystring)
print(response.json())
# Out:
# {'success': False, 'error': {'code': 301, 'type': 'invalid_fields', 'info': 'One or more invalid fields were specified using the fields parameter.'}}

# %%
import http.client
conn = http.client.HTTPSConnection("api.marketstack.com")
conn.request("GET", "/v1/eod?access_key=d1eded6c0098d3d93e45ae01101cf626&symbols=AAPL")
res = conn.getresponse()
data = res.read()
print(data)
# Out:
# b'{"pagination":{"limit":100,"offset":0,"count":100,"total":100},"data":[{"open":310.13,"high":319.2799,"low":309.6,"close":316.83,"volume":50009121.0,"adj_high":319.2799,"adj_low":309.6,"adj_close":316.83,"adj_open":310.13,"adj_volume":50505646.0,"split_factor":1.0,"dividend":0.0,"symbol":"AAPL","exchange":"XNAS","date":"2026-08-19T00:00:00+0000"},{"open":307.53,"high":311.49,"low":305.74,"close":310.03,"volume":46601840.0,"adj_high":311.49,"adj_low":305.74,"adj_close":310.03,"adj_open":307.53,"adj_volume":53424535.0,"split_factor":1.0,"dividend":0.0,"symbol":"AAPL","exchange":"XNAS","date":"2026-08-18T00:00:00+0000"},{"open":306.21,"high":307.66,"low":302.939,"close":305.59,"volume":32743947.0,"adj_high":307.66,"adj_low":302.939,"adj_close":305.59,"adj_open":306.21,"adj_volume":38169263.0,"split_factor":1.0,"dividend":0.0,"symbol":"AAPL","exchange":"XNAS","date":"2026-08-17T00:00:00+0000"},{"open":306.028,"high":307.49,"low":304.3,"close":305.93,"volume":26072932.0,"adj_high":307.4
# ...

# %% [markdown]
# Tiingo

# %%
import requests

headers = {
        'Content-Type': 'application/json'
        }
requestResponse = requests.get("https://api.tiingo.com/api/test?token=efe89eb62befd460366a11b67d5a14ed3f43583a",
                                    headers=headers)
print(requestResponse.json())
# Out:
# {'message': 'You successfully sent a request'}

# %%
import requests

headers = {
        'Content-Type': 'application/json',
        'Authorization' : 'Token efe89eb62befd460366a11b67d5a14ed3f43583a'
        }
requestResponse = requests.get("https://api.tiingo.com/api/test/",
                                    headers=headers)
print(requestResponse.json())
# Out:
# {'message': 'You successfully sent a request'}

# %%
import requests
headers = {
    'Content-Type': 'application/json'
}
requestResponse = requests.get("https://api.tiingo.com/tiingo/daily/aapl/prices?startDate=2019-01-02&token=efe89eb62befd460366a11b67d5a14ed3f43583a", headers=headers)
print(requestResponse.json())
